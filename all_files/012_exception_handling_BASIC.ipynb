# %%
# Divide by Zero: Write code that attempts to divide a number by zero. 
# What exception is raised in this case, and how can you handle it using a try-except block?

#number = 7
#print(number/0) ## ZeroDivisionError is raised and it can be handled as below:

try:
    number = int(input("Enter number"))
    if number < 0:
        raise ValueError(" Number must be greater than 0") ## raising custom exception which needs to be catched by except
    print(number/0)

except ZeroDivisionError:
    print("can't divide number by zero")
except ValueError as ve:
    print("Error: ", ve)



# Invalid Input: Create a program that takes user input for two numbers and performs division. 
# How can you handle the case where the user enters non-numeric input? 
# Implement error handling for this scenario.

try:

    number1 = int(input("Enter number1"))
    number2 = int(input("Enter number2"))

    print(number1/number2)

except ValueError as e:
    print(f'Error is {e}')


# Missing Variable: Attempt to print the value of a variable that hasn't been defined. What exception does Python raise, and how can you handle it gracefully?
try:
    print(a)

except NameError as E:
    print(f'Error is {E}')

# Index Error: Try to access an element of a list using an index that is out of range. 
# What is the name of the exception raised, and how can you catch it using a try-except block?
try:
    lst = [1,3,5,6,7]
    i = 0
    while i <= len(lst):
        print(lst[i])
        i+=1

except IndexError as IE:
    print(IE)

# Type Error: Add a string and an integer together. What exception occurs, 
# and how can you handle type errors in Python?
try:
    string = "Hello, GoodMorning"
    number = 7

    print(string+number)

except TypeError as TE:
    print(TE)


# File Not Found: Attempt to open a non-existent file using the open() function.  #study, do after file-handling
# What exception is raised, and how can you handle file-related exceptions?




# Custom Exception: Define a custom exception class called CustomError 
# and raise it in your code. How can you create and raise custom exceptions in Python?

class CustomError(NameError): ## the argument passed to the class CustomError must be inherited from the BaseException class
    pass

try:
    text = input("Enter Fullname")
    if text != text.upper():
        raise CustomError("Fullname must be in Capital Letters")
    print(text)
except CustomError as CE: 
    print("CustomError is:", CE)


# Catch Multiple Exceptions: Modify your program to handle both 
# ZeroDivisionError and ValueError exceptions when performing division. 
# How can you catch multiple exceptions in a single try-except block?

try:
    n1 = int(input("Enter number1"))
    n2 = int(input("Enter number2"))
    print(n1/n2)
except(ZeroDivisionError, ValueError) as e:
    print("Error is:",e)

# Finally Block: Use a finally block in combination 
# with try and except to ensure that a piece of code is always executed, 
# regardless of whether an exception occurs or not. What is the purpose of the finally block?

#ANS: Finally block will be executed no matter whichever error is raised and if isn't catched too.
# In the below example ZeroDivisionError is raised and catched using except, after handling this the finally block is executed. In other scenario there is a chance of ValueError raising
# which isn't handled below, even though the finally block is executed and the program has stopped abruptly
try:
    n1 = int(input("Enter number1"))
    n2 = int(input("Enter number2"))
    print(n1/n2)
except(ZeroDivisionError) as e:
    print("Error is:",e)
finally:
    print("Need to start other program")


# Raising Exceptions: Write code that raises an exception with a 
# specific message using the raise keyword. 
# How can you raise exceptions with custom error messages in Python?

try:
    number = int(input("Enter number"))
    if number>100:
        raise ValueError("Number must be between 0 and 100")
    
except ValueError as E:
    print(E)
