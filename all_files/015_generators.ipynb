# %%
def even_numbers(limit):
    for i in range(2, limit + 1, 2):
        yield i

# Usage example:
even_gen = even_numbers(10)
print(list(even_gen))
# Out:
# [2, 4, 6, 8, 10]

# %%
# What is a generator in Python, and how does it differ from a regular function?
# ANS: Generators has some sort of similar prototype to regular functions. But generators holds the property of iterating objects one by one and returns it.
#      The usual function returns any object or value, but generator returns final iterable object

# How do you define a generator function in Python?
def gen_fun(number):
    for i in range(number):
        yield i

gen_fun(5)
print(list(gen_fun(5)))

# Explain the yield keyword and its purpose in a generator function.
# ANS: It returns a value or stores the value to the iterable object and returns the final iterable object

# What happens when you call a generator function? Does it execute immediately?
# ANS: No it doesn't execute immediately, the generator function returns the iterable object which needs to be iterated for displaying sequence of values.

# What is the benefit of using generators when dealing with large datasets?
# ANS: while handling large datasets using list comprehensions, the entire values are assigned memeory and calculations needs performance issues.
# But using generator functions the whole processing is not done initially, instead calling the generator function returns the generator which needs to be iterated to get the sequence of values.

# How can you iterate through the values generated by a generator function?
# ANS: resulted_iterator = generator_function(6)
#   for i in resulted_iterator:
#       print(i)
       
# What is the difference between a generator and a list comprehension in terms of memory usage?
# ANS: Using generator makes use of less memeory compared to the list comprehension because, 'list comprehensions' allocates memory to the entire values but returning a generator doesn't allocate memory and 
# next the values can be returned and memory will be allocated, by iterating this generator 

# Can you create an infinite generator? If so, how? # Study
# ANS: 

# How do you stop or exit a generator's execution?
#ANS: By throwing an stopIterationError, or by using break or return statement

# What is lazy evaluation, and how does it relate to generators?  #study

# What are the advantages of generators over lists when working with large sequences of data?
# ANS: Generators have better performance and memomry handling compared to the lists in terms of large sets of data. Because accessing lists need 
# memory allocation to the all the values, instead generators can be iterated over to access the value or values as an object for which memory can
# be allocated. 

# How do you create a generator expression? Provide an example.
# ANS: generator_1 = ( x*2 for x in range(100))
# print([next(generator_1) for _ in range(10)]) ## iterates the generator for 10 items  and stores the values in the list.

# Explain the concept of generator comprehensions.
# As said above generator is created in the first line of code using comprehensions and the elements can be returned on request.

# What is the difference between a generator function and a regular function that returns a list?
# ANS: A regular function computes the input parameter and returns the computed value, whereas calling the generator function dosen't run the code 
# and returns the value. Instead generator is returned as Iterable object and the values can be accessed by the iteratoring this generator through for loop.

# How do you access the values generated by a generator in a loop?
# ANS: By iterating the generator through for loop, it iterates single value at a time which can be printed.

# Can you use the next() function to manually iterate through a generator's values?
# by passing the generator through the next() method, the current state is saved and returns the value one at a time.

# How does exception handling work with generators? How can you handle exceptions in a generator?
# By throwing an exception and handling that with try and except

# What is the purpose of the return statement in a generator function?
# To stop the execution of generator function

# How can you pass arguments to a generator function when creating an instance of the generator?
# Its similiar to the normal function

# When is it appropriate to use generators in your Python code?
# when in need to access and process large data sets
# Out:
# [0, 1, 2, 3, 4]
